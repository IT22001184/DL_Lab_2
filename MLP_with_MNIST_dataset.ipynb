# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
import tensorflow as tf
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# Load the MNIST dataset

# %%
(train_data,train_target),(test_data,test_target) = mnist.load_data()

# %% [markdown]
# Visualize the dataset

# %%
fig, axs = plt.subplots(2, 5, figsize=(16,8))
random_numbers = np.random.randint(0, 60000, 10)
print('Target labels: ',train_target[random_numbers])
for idx, ax in enumerate(axs.ravel()):
    ax.imshow(train_data[random_numbers[idx]],cmap='gray')
plt.show()
# Out:
# Target labels:  [8 1 2 5 7 3 8 3 5 8]

# %% [markdown]
# Pre-processing stage

# %%
new_train_data = train_data/255.0
new_test_data=test_data/255.0

new_train_target = to_categorical(train_target)
new_test_target = to_categorical(test_target)

# %% [markdown]
# Create the Model architecture

# %%
model=Sequential()

model.add(Flatten(input_shape=(28,28)))

model.add(Dense(64,activation='relu'))
model.add(Dense(64,input_dim=64,activation='relu'))
model.add(Dense(32,input_dim=64,activation='relu'))
model.add(Dense(10,input_dim=32,activation='softmax'))
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_5 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 64)             │        50,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_24 (Dense)                │ (None, 10)             │           330 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 56,810 (221.91 KB)
#  Trainable params: 56,810 (221.91 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Train the model

# %%
train_info = model.fit(new_train_data , new_train_target , epochs = 10)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8348 - loss: 0.5481
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9581 - loss: 0.1365
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9723 - loss: 0.0914
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9776 - loss: 0.0707
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9819 - loss: 0.0584
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9845 - loss: 0.0488
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9876 - loss: 0.0399
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.9892 - loss: 0.0336
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9889 - loss: 0.0321
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9914 - loss: 0.0269

# %% [markdown]
# Plot the loss and accuracy graphs

# %%
plt.plot(train_info.history['loss'])
plt.xlabel('epochs')
plt.ylabel('loss')
plt.title('Model loss')
plt.show()

# %%
plt.plot(train_info.history['accuracy'])
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.title('Model accuracy')
plt.show()

# %% [markdown]
# Test the performance of Model

# %%
loss, acc = model.evaluate(new_test_data , new_test_target)
print(f'Loss of the Test dataset is: {loss}\nAccuracy of the test dataset is: {acc}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9736 - loss: 0.1658
# Loss of the Test dataset is: 0.1457185447216034
# Accuracy of the test dataset is: 0.9776999950408936

# %% [markdown]
# Save the model weights

# %%
model.save_weights('MNIST_WEIGHTS_V1.weights.h5')

# %% [markdown]
# a.
# Improve the test accuracy of the model by changing the hyperparameters.

# %%
model = Sequential()
model.add(Flatten(input_shape=(28,28)))
model.add(Dense(128, activation='relu'))  # increased neurons
model.add(Dense(128, activation='relu'))  # increased neurons
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))

optimizer = Adam(learning_rate=0.001)  # default, can tune
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# Train with more epochs and batch size
train_info = model.fit(new_train_data, new_train_target, epochs=50, batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.8333 - loss: 0.5539 - val_accuracy: 0.9540 - val_loss: 0.1566
# Epoch 2/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9618 - loss: 0.1246 - val_accuracy: 0.9634 - val_loss: 0.1232
# Epoch 3/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9756 - loss: 0.0792 - val_accuracy: 0.9670 - val_loss: 0.1115
# Epoch 4/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9810 - loss: 0.0615 - val_accuracy: 0.9731 - val_loss: 0.0959
# Epoch 5/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9853 - loss: 0.0447 - val_accuracy: 0.9693 - val_loss: 0.1088
# Epoch 6/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9888 - loss: 0.0357 - val_accuracy: 0.9747 - val_loss: 0.0949
# Epoch 7/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9902 - loss: 0.0311 - val_accuracy: 0.9718 - val_loss: 0.1126
# Epoch 8/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9918 - loss: 0.0239 - val_accuracy: 0.9748 - val_loss: 0.0980
# Epoch 9/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9930 - loss: 0.0215 - val_accuracy: 0.9718 - val_loss: 0.1207
# Epoch 10/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.9935 - loss: 0.0203 - val_accuracy: 0.9750 - val_loss: 0.1073
# Epoch 11/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9958 - loss: 0.0133 - val_accuracy: 0.9737 - val_loss: 0.1237
# Epoch 12/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9948 - loss: 0.0155 - val_accuracy: 0.9718 - val_loss: 0.1336
# Epoch 13/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9926 - loss: 0.0242 - val_accuracy: 0.9768 - val_loss: 0.1164
# Epoch 14/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9954 - loss: 0.0127 - val_accuracy: 0.9758 - val_loss: 0.1341
# Epoch 15/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9961 - loss: 0.0128 - val_accuracy: 0.9734 - val_loss: 0.1440
# Epoch 16/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9943 - loss: 0.0166 - val_accuracy: 0.9765 - val_loss: 0.1279
# Epoch 17/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9962 - loss: 0.0113 - val_accuracy: 0.9762 - val_loss: 0.1235
# Epoch 18/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9975 - loss: 0.0084 - val_accuracy: 0.9728 - val_loss: 0.1589
# Epoch 19/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9969 - loss: 0.0095 - val_accuracy: 0.9737 - val_loss: 0.1516
# Epoch 20/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9963 - loss: 0.0114 - val_accuracy: 0.9718 - val_loss: 0.1570
# Epoch 21/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9956 - loss: 0.0122 - val_accuracy: 0.9734 - val_loss: 0.1524
# Epoch 22/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9979 - loss: 0.0060 - val_accuracy: 0.9751 - val_loss: 0.1539
# Epoch 23/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9979 - loss: 0.0073 - val_accuracy: 0.9722 - val_loss: 0.1636
# Epoch 24/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9962 - loss: 0.0119 - val_accuracy: 0.9725 - val_loss: 0.1597
# Epoch 25/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9975 - loss: 0.0069 - val_accuracy: 0.9760 - val_loss: 0.1497
# Epoch 26/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9967 - loss: 0.0104 - val_accuracy: 0.9751 - val_loss: 0.1458
# Epoch 27/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9968 - loss: 0.0101 - val_accuracy: 0.9756 - val_loss: 0.1517
# Epoch 28/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9977 - loss: 0.0075 - val_accuracy: 0.9764 - val_loss: 0.1408
# Epoch 29/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9987 - loss: 0.0035 - val_accuracy: 0.9773 - val_loss: 0.1460
# Epoch 30/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9973 - loss: 0.0104 - val_accuracy: 0.9762 - val_loss: 0.1630
# Epoch 31/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9979 - loss: 0.0069 - val_accuracy: 0.9758 - val_loss: 0.1543
# Epoch 32/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9975 - loss: 0.0077 - val_accuracy: 0.9758 - val_loss: 0.1470
# Epoch 33/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9994 - loss: 0.0026 - val_accuracy: 0.9727 - val_loss: 0.1869
# Epoch 34/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9965 - loss: 0.0118 - val_accuracy: 0.9776 - val_loss: 0.1572
# Epoch 35/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9978 - loss: 0.0068 - val_accuracy: 0.9747 - val_loss: 0.1670
# Epoch 36/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9979 - loss: 0.0073 - val_accuracy: 0.9728 - val_loss: 0.1785
# Epoch 37/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9972 - loss: 0.0092 - val_accuracy: 0.9744 - val_loss: 0.1764
# Epoch 38/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9988 - loss: 0.0044 - val_accuracy: 0.9804 - val_loss: 0.1518
# Epoch 39/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9989 - loss: 0.0038 - val_accuracy: 0.9772 - val_loss: 0.1764
# Epoch 40/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9982 - loss: 0.0063 - val_accuracy: 0.9772 - val_loss: 0.1585
# Epoch 41/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9985 - loss: 0.0042 - val_accuracy: 0.9753 - val_loss: 0.1811
# Epoch 42/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9985 - loss: 0.0053 - val_accuracy: 0.9712 - val_loss: 0.1874
# Epoch 43/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9982 - loss: 0.0060 - val_accuracy: 0.9761 - val_loss: 0.1724
# Epoch 44/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9987 - loss: 0.0041 - val_accuracy: 0.9771 - val_loss: 0.1788
# Epoch 45/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9973 - loss: 0.0101 - val_accuracy: 0.9724 - val_loss: 0.2164
# Epoch 46/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9968 - loss: 0.0126 - val_accuracy: 0.9774 - val_loss: 0.1650
# Epoch 47/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9987 - loss: 0.0041 - val_accuracy: 0.9767 - val_loss: 0.1762
# Epoch 48/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9991 - loss: 0.0028 - val_accuracy: 0.9758 - val_loss: 0.1906
# Epoch 49/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9989 - loss: 0.0045 - val_accuracy: 0.9768 - val_loss: 0.1818
# Epoch 50/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9973 - loss: 0.0094 - val_accuracy: 0.9758 - val_loss: 0.1706

# %% [markdown]
# b.
# Add L1 and L2 regularization terms to the model and retrain the model.

# %%
model = Sequential()
model.add(Flatten(input_shape=(28,28)))
model.add(Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
model.add(Dense(128, activation='relu', kernel_regularizer=regularizers.l1(0.001)))
model.add(Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
model.add(Dense(10, activation='softmax'))

optimizer = Adam(learning_rate=0.001)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

train_info = model.fit(new_train_data, new_train_target, epochs=50, batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.8308 - loss: 1.5054 - val_accuracy: 0.9457 - val_loss: 0.5647
# Epoch 2/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9422 - loss: 0.5323 - val_accuracy: 0.9532 - val_loss: 0.4152
# Epoch 3/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9530 - loss: 0.3999 - val_accuracy: 0.9537 - val_loss: 0.3612
# Epoch 4/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9613 - loss: 0.3282 - val_accuracy: 0.9630 - val_loss: 0.3096
# Epoch 5/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9655 - loss: 0.2919 - val_accuracy: 0.9665 - val_loss: 0.2771
# Epoch 6/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9697 - loss: 0.2622 - val_accuracy: 0.9637 - val_loss: 0.2682
# Epoch 7/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9705 - loss: 0.2448 - val_accuracy: 0.9663 - val_loss: 0.2538
# Epoch 8/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9735 - loss: 0.2268 - val_accuracy: 0.9667 - val_loss: 0.2436
# Epoch 9/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9745 - loss: 0.2173 - val_accuracy: 0.9651 - val_loss: 0.2410
# Epoch 10/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9744 - loss: 0.2094 - val_accuracy: 0.9663 - val_loss: 0.2408
# Epoch 11/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9751 - loss: 0.2046 - val_accuracy: 0.9691 - val_loss: 0.2208
# Epoch 12/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9777 - loss: 0.1940 - val_accuracy: 0.9670 - val_loss: 0.2215
# Epoch 13/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9772 - loss: 0.1892 - val_accuracy: 0.9713 - val_loss: 0.2055
# Epoch 14/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9766 - loss: 0.1845 - val_accuracy: 0.9708 - val_loss: 0.2086
# Epoch 15/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9792 - loss: 0.1768 - val_accuracy: 0.9687 - val_loss: 0.2096
# Epoch 16/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9792 - loss: 0.1753 - val_accuracy: 0.9705 - val_loss: 0.2017
# Epoch 17/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9801 - loss: 0.1729 - val_accuracy: 0.9674 - val_loss: 0.2083
# Epoch 18/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9793 - loss: 0.1702 - val_accuracy: 0.9669 - val_loss: 0.2086
# Epoch 19/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9805 - loss: 0.1655 - val_accuracy: 0.9678 - val_loss: 0.2100
# Epoch 20/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9797 - loss: 0.1675 - val_accuracy: 0.9693 - val_loss: 0.1991
# Epoch 21/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9811 - loss: 0.1606 - val_accuracy: 0.9707 - val_loss: 0.1929
# Epoch 22/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9801 - loss: 0.1616 - val_accuracy: 0.9642 - val_loss: 0.2111
# Epoch 23/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9797 - loss: 0.1585 - val_accuracy: 0.9617 - val_loss: 0.2195
# Epoch 24/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9806 - loss: 0.1590 - val_accuracy: 0.9682 - val_loss: 0.2051
# Epoch 25/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9813 - loss: 0.1552 - val_accuracy: 0.9657 - val_loss: 0.2100
# Epoch 26/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9824 - loss: 0.1546 - val_accuracy: 0.9673 - val_loss: 0.2027
# Epoch 27/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9821 - loss: 0.1520 - val_accuracy: 0.9677 - val_loss: 0.1991
# Epoch 28/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9816 - loss: 0.1515 - val_accuracy: 0.9657 - val_loss: 0.2053
# Epoch 29/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9809 - loss: 0.1517 - val_accuracy: 0.9672 - val_loss: 0.1992
# Epoch 30/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9818 - loss: 0.1504 - val_accuracy: 0.9700 - val_loss: 0.1921
# Epoch 31/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9824 - loss: 0.1496 - val_accuracy: 0.9706 - val_loss: 0.1897
# Epoch 32/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9818 - loss: 0.1482 - val_accuracy: 0.9663 - val_loss: 0.1974
# Epoch 33/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9819 - loss: 0.1481 - val_accuracy: 0.9696 - val_loss: 0.1813
# Epoch 34/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9829 - loss: 0.1461 - val_accuracy: 0.9651 - val_loss: 0.2039
# Epoch 35/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9821 - loss: 0.1455 - val_accuracy: 0.9674 - val_loss: 0.2016
# Epoch 36/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9832 - loss: 0.1427 - val_accuracy: 0.9654 - val_loss: 0.2009
# Epoch 37/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9830 - loss: 0.1426 - val_accuracy: 0.9684 - val_loss: 0.1930
# Epoch 38/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9831 - loss: 0.1431 - val_accuracy: 0.9659 - val_loss: 0.2037
# Epoch 39/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9832 - loss: 0.1417 - val_accuracy: 0.9696 - val_loss: 0.1883
# Epoch 40/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9813 - loss: 0.1456 - val_accuracy: 0.9645 - val_loss: 0.2012
# Epoch 41/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9817 - loss: 0.1449 - val_accuracy: 0.9699 - val_loss: 0.1829
# Epoch 42/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9829 - loss: 0.1423 - val_accuracy: 0.9702 - val_loss: 0.1825
# Epoch 43/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9816 - loss: 0.1429 - val_accuracy: 0.9621 - val_loss: 0.2139
# Epoch 44/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9839 - loss: 0.1374 - val_accuracy: 0.9683 - val_loss: 0.1932
# Epoch 45/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9835 - loss: 0.1392 - val_accuracy: 0.9679 - val_loss: 0.1896
# Epoch 46/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9836 - loss: 0.1371 - val_accuracy: 0.9653 - val_loss: 0.1997
# Epoch 47/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9830 - loss: 0.1405 - val_accuracy: 0.9653 - val_loss: 0.2002
# Epoch 48/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9822 - loss: 0.1419 - val_accuracy: 0.9629 - val_loss: 0.2052
# Epoch 49/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9822 - loss: 0.1370 - val_accuracy: 0.9676 - val_loss: 0.1965
# Epoch 50/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9841 - loss: 0.1361 - val_accuracy: 0.9688 - val_loss: 0.1819

# %% [markdown]
# c.
# Visualize class-wise test dataset performance using a confusion matrix.

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Predict classes for test set
y_pred = model.predict(new_test_data)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(new_test_target, axis=1)

# Compute confusion matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap='Blues')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
